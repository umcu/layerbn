# %% [markdown]
# # HART-BREIN Bayesian Network preprocessing pipeline
#
# This notebook recreates the original `preprocess_data.py` pipeline in an interactive way.
#
# **Goals**
#
# - Load raw HART-BREIN data (SPSS + Excel/CSV).
# - Derive clinical outcomes (MACE, CDR increase, dropout).
# - Build the Bayesian network metadata table (layers and variable names).
# - Create:
#   - `df.parquet` – cleaned analysis dataset.
#   - `df_imp.parquet` – imputed version of `df.parquet`.
#   - `bn_vars.parquet` – variable metadata with layers.
#   - `baseline_table_by_group.(csv|parquet)` – baseline characteristics per patient group.
#
# Use this notebook to:
# - Adjust paths and settings.
# - Inspect intermediate data (e.g. `.head()`, `.info()`, distributions).
# - Verify that each step behaves as expected.

# %%
# Cell 1 – Imports and logging

from __future__ import annotations

import logging
from dataclasses import dataclass
from pathlib import Path
from typing import Iterable, Mapping, Sequence

import numpy as np
import yaml
import pandas as pd
import re
from pandas.api.types import CategoricalDtype
import pyreadstat
from sklearn.experimental import enable_iterative_imputer  # noqa: F401
from sklearn.impute import IterativeImputer

LOGGER = logging.getLogger(__name__)
logging.basicConfig(level=logging.INFO, format="%(levelname)s %(message)s")

pd.set_option("display.max_columns", 120)
pd.set_option("display.width", 180)

# %% [markdown]
# ## Configuration
#
# This section replaces the CLI interface of the original script.
#
# - Set `PROJECT_ROOT` to the root of your project.
# - Optionally define:
#   - `RISK_REGION`: SCORE2 risk region (`"Low"`, `"Moderate"`, `"High"`, `"Very high"`).
#   - `RAW_DIR`, `OUTPUT_DIR`, `CODEBOOK_PATH`.
# - Optionally load additional path overrides from `config/data_paths.yml`.

# %%
# Cell 2 – Configuration dataclass

@dataclass
class PreprocessConfig:
    """Configuration for the preprocessing run."""

    project_root: Path
    risk_region: str = "Low"
    raw_dir: Path | None = None
    output_dir: Path | None = None
    codebook_path: Path | None = None
    seed: int = 1234

    def __post_init__(self) -> None:
        self.project_root = self.project_root.resolve()
        self.raw_dir = (self.project_root / "data" ) if self.raw_dir is None else self.raw_dir
        self.output_dir = (self.project_root / "data") if self.output_dir is None else self.output_dir
        default_codebook = self.project_root / "data" / "meta" / "HBC_CODEBOOK_LABELS.xlsx"
        self.codebook_path = default_codebook if self.codebook_path is None else self.codebook_path

    def apply_overrides(self, overrides: Mapping[str, str]) -> None:
        """Apply path/risk_region overrides from a YAML dictionary."""

        def _as_path(value: str | None) -> Path | None:
            if value in (None, ""):
                return None
            path = Path(value)
            if not path.is_absolute():
                path = (self.project_root / path).resolve()
            return path

        if not overrides:
            return
        if "risk_region" in overrides:
            self.risk_region = str(overrides["risk_region"])
        if "raw_dir" in overrides:
            self.raw_dir = _as_path(overrides["raw_dir"]) or self.raw_dir
        if "output_dir" in overrides:
            self.output_dir = _as_path(overrides["output_dir"]) or self.output_dir
        if "codebook_path" in overrides:
            self.codebook_path = _as_path(overrides["codebook_path"]) or self.codebook_path

# %%
# Cell 3 – Instantiate config from config.yml

from pathlib import Path

# Locate config.yml — same file used by 01_bayesian_network.ipynb
_config_candidates = [
    Path.cwd() / 'config.yml',
    Path.cwd() / 'projects' / 'HBC' / 'config.yml',
]
_config_path = next((p for p in _config_candidates if p.exists()), None)
if _config_path is None:
    raise FileNotFoundError(
        "config.yml not found. Expected it next to the notebook or at projects/HBC/config.yml."
    )

with open(_config_path) as _f:
    overrides = yaml.safe_load(_f) or {}

PROJECT_ROOT = Path(overrides['project_root']).expanduser().resolve()

config = PreprocessConfig(
    project_root=PROJECT_ROOT,
    raw_dir=Path(overrides['raw_dir']).expanduser(),
    output_dir=Path(overrides['output_dir']).expanduser(),
    codebook_path=Path(overrides['codebook_path']).expanduser(),
    risk_region=overrides.get('risk_region', 'Low'),
    seed=1234,
)

print(f"Config       : {_config_path}")
print(f"PROJECT_ROOT : {config.project_root}")
print(f"raw_dir      : {config.raw_dir}")
print(f"output_dir   : {config.output_dir}")
print(f"codebook     : {config.codebook_path}")
# Out:
# Config       : <PROJECT_ROOT>/04_VCI_BAYES/projects/HBC/config.yml
# PROJECT_ROOT : <PROJECT_ROOT>/04_BAYESIAN_OUTPUT
# raw_dir      : <PROJECT_ROOT>/04_BAYESIAN_OUTPUT/data
# output_dir   : <PROJECT_ROOT>/04_BAYESIAN_OUTPUT/output
# codebook     : <PROJECT_ROOT>/04_BAYESIAN_OUTPUT/data/HBC_CODEBOOK_LABELS.xlsx

# %% [markdown]
# ## SCORE2 cardiovascular risk function
#
# This section is a direct port of the SCORE2 risk computation from the original script.
#
# - `score2(...)` computes a 10-year CVD risk percentage for a single row.
# - `classify=True` returns risk category labels instead of numeric percentages.

# %%
# Cell 4 – SCORE2 implementation

def score2(
    *,
    risk_region: str,
    age: float,
    gender: str,
    smoker: float,
    systolic_bp: float,
    diabetes: float,
    total_chol: float,
    total_hdl: float,
    classify: bool = False,
) -> float | str | None:
    """Compute SCORE2 cardiovascular risk for a single patient."""

    gender = gender.lower() if isinstance(gender, str) else gender
    if gender not in {"male", "female"}:
        return None

    scale1 = scale2 = None
    rr = risk_region.lower()
    if age < 70:
        if rr == "low" and gender == "male":
            scale1, scale2 = -0.5699, 0.7476
        elif rr == "low" and gender == "female":
            scale1, scale2 = -0.738, 0.7019
        elif rr == "moderate" and gender == "male":
            scale1, scale2 = -0.1565, 0.8009
        elif rr == "moderate" and gender == "female":
            scale1, scale2 = -0.3143, 0.7701
        elif rr == "high" and gender == "male":
            scale1, scale2 = 0.3207, 0.936
        elif rr == "high" and gender == "female":
            scale1, scale2 = 0.571, 0.9369
        elif rr == "very high" and gender == "male":
            scale1, scale2 = 0.5836, 0.8294
        elif rr == "very high" and gender == "female":
            scale1, scale2 = 0.9412, 0.8329
    else:
        if rr == "low" and gender == "male":
            scale1, scale2 = -0.34, 1.19
        elif rr == "low" and gender == "female":
            scale1, scale2 = -0.52, 1.01
        elif rr == "moderate" and gender == "male":
            scale1, scale2 = 0.01, 1.25
        elif rr == "moderate" and gender == "female":
            scale1, scale2 = -0.1, 1.1
        elif rr == "high" and gender == "male":
            scale1, scale2 = 0.08, 1.15
        elif rr == "high" and gender == "female":
            scale1, scale2 = 0.38, 1.09
        elif rr == "very high" and gender == "male":
            scale1, scale2 = 0.05, 0.7
        elif rr == "very high" and gender == "female":
            scale1, scale2 = 0.38, 0.69
    if scale1 is None or scale2 is None:
        LOGGER.warning("Risk region specification required for SCORE2 computation; returning None")
        return None

    smoker = float(smoker) if smoker is not None else 0.0
    diabetes = float(diabetes) if diabetes is not None else 0.0

    def _calc_under70() -> float:
        if gender == "male":
            term = (
                0.3742 * (age - 60) / 5
                + 0.6012 * smoker
                + 0.2777 * (systolic_bp - 120) / 20
                + 0.6457 * diabetes
                + 0.1458 * (total_chol - 6) / 1
                - 0.2698 * (total_hdl - 1.3) / 0.5
                - 0.0755 * (age - 60) / 5 * smoker
                - 0.0255 * (age - 60) / 5 * (systolic_bp - 120) / 20
                - 0.0281 * (age - 60) / 5 * (total_chol - 6) / 1
                + 0.0426 * (age - 60) / 5 * (total_hdl - 1.3) / 0.5
                - 0.0983 * (age - 60) / 5 * diabetes
            )
            tmp = 1 - 0.9605 ** np.exp(term)
            return 1 - np.exp(-np.exp(scale1 + scale2 * np.log(-np.log(1 - tmp))))
        else:
            term = (
                0.4648 * (age - 60) / 5
                + 0.7744 * smoker
                + 0.3131 * (systolic_bp - 120) / 20
                + 0.8096 * diabetes
                + 0.1002 * (total_chol - 6) / 1
                - 0.2606 * (total_hdl - 1.3) / 0.5
                - 0.1088 * (age - 60) / 5 * smoker
                - 0.0277 * (age - 60) / 5 * (systolic_bp - 120) / 20
                - 0.0226 * (age - 60) / 5 * (total_chol - 6) / 1
                + 0.0613 * (age - 60) / 5 * (total_hdl - 1.3) / 0.5
                - 0.1272 * (age - 60) / 5 * diabetes
            )
            tmp = 1 - 0.9776 ** np.exp(term)
            return 1 - np.exp(-np.exp(scale1 + scale2 * np.log(-np.log(1 - tmp))))

    def _calc_over70() -> float:
        if gender == "male":
            term = (
                0.0634 * (age - 73)
                + 0.4245 * diabetes
                + 0.3524 * smoker
                + 0.0094 * (systolic_bp - 150)
                + 0.085 * (total_chol - 6)
                - 0.3564 * (total_hdl - 1.4)
                - 0.0174 * (age - 73) * diabetes
                - 0.0247 * (age - 73) * smoker
                - 0.0005 * (age - 73) * (systolic_bp - 150)
                + 0.0073 * (age - 73) * (total_chol - 6)
                + 0.0091 * (age - 73) * (total_hdl - 1.4)
            )
            tmp = 1 - 0.7576 ** np.exp(term - 0.0929)
            return 1 - np.exp(-np.exp(scale1 + scale2 * np.log(-np.log(1 - tmp))))
        else:
            term = (
                0.0789 * (age - 73)
                + 0.601 * diabetes
                + 0.4921 * smoker
                + 0.0102 * (systolic_bp - 150)
                + 0.0605 * (total_chol - 6)
                - 0.304 * (total_hdl - 1.4)
                - 0.0107 * (age - 73) * diabetes
                - 0.0255 * (age - 73) * smoker
                - 0.0004 * (age - 73) * (systolic_bp - 150)
                - 0.0009 * (age - 73) * (total_chol - 6)
                + 0.0154 * (age - 73) * (total_hdl - 1.4)
            )
            tmp = 1 - 0.8082 ** np.exp(term - 0.229)
            return 1 - np.exp(-np.exp(scale1 + scale2 * np.log(-np.log(1 - tmp))))

    risk = _calc_under70() if age < 70 else _calc_over70()
    if np.isnan(risk):
        return None
    risk_pct = round(risk * 100, 1)

    if classify:
        if age < 50:
            if risk_pct < 2.5:
                return "Low risk"
            if risk_pct < 7.5:
                return "Moderate risk"
            return "High risk"
        if age <= 69:
            if risk_pct < 5:
                return "Low risk"
            if risk_pct < 10:
                return "Moderate risk"
            return "High risk"
        if risk_pct < 7.5:
            return "Low risk"
        if risk_pct < 15:
            return "Moderate risk"
        return "High risk"
    return risk_pct

# %% [markdown]
# ## General data helpers
#
# - `read_sav`: SPSS loader.
# - `apply_value_labels`: applies value labels from SPSS metadata.
# - `coalesce`: dplyr-style coalesce across columns.
# - `to_datetime`: parse date columns.
# - `map_cdr_values`: remap CDR scoring as in original R script.

# %%
# Cell 5 – Basic helpers

def read_sav(path: Path) -> tuple[pd.DataFrame, object]:
    if not path.exists():
        raise FileNotFoundError(path)
    return pyreadstat.read_sav(path)


def apply_value_labels(df: pd.DataFrame, meta) -> pd.DataFrame:
    """Replace numeric codes with SPSS value labels when available."""
    if meta is None or not getattr(meta, "value_labels", None):
        return df

    result = df.copy()
    value_sets = meta.value_labels
    variable_map = getattr(meta, "variable_value_labels", {})

    for column, label_set in variable_map.items():
        if column not in result.columns:
            continue
        if isinstance(label_set, dict):
            mapping = label_set
        else:
            mapping = value_sets.get(label_set, {})
        if mapping:
            result[column] = result[column].replace(mapping)
    return result


def coalesce(df: pd.DataFrame, cols: Sequence[str], target: str) -> None:
    """Replicate dplyr::coalesce behaviour across multiple columns."""
    series = None
    for col in cols:
        if col not in df:
            continue
        series = df[col] if series is None else series.fillna(df[col])
    if series is not None:
        df[target] = series


def to_datetime(df: pd.DataFrame, columns: Iterable[str]) -> None:
    for col in columns:
        if col in df:
            df[col] = pd.to_datetime(df[col], errors="coerce")


def map_cdr_values(series: pd.Series) -> pd.Series:
    mapping = {1: 0.5, 2: 1.0, 3: 2.0, 4: 3.0}
    return series.replace(mapping)

# %% [markdown]
# ## Outcome derivation
#
# This reproduces the outcome logic from the original `build_outcomes` function:
#
# - Coalesces duplicated T2/T4 variables.
# - Derives:
#   - Stroke events.
#   - MACE (baseline + follow-up).
#   - Dropout reasons (cleaned, normalized).
#   - `OUTCOME_MACE` and `OUTCOME_CDR_INCREASE` with `"Yes" / "No" / "Unobserved"`.

# %%
# Cell 6 – Outcome construction

def build_outcomes(df_fu: pd.DataFrame) -> tuple[pd.DataFrame, pd.DataFrame]:
    """Reproduce the outcome derivations from 01-A.R."""
    outcome_cols = [
        "patientID",
        "T0_datumbaselinebezoek_E1_C1",
        "T2_datumfu2bezoek_E3_C10",
        "T4_datum_tel_int_E4_C12",
        "T0_CDR_E1_C1",
        "T2_CDR_E3_C10",
        "T2_CDR_E3_C11",
        "T4_CDR_E4_C12",
        "T2_reden_geen_deelname_E3_C11",
        "T4_reden_geen_deelname_E4_C12",
        "T0_CVA_E1_C1",
        "T0_hartinfarct_E1_C1",
        "T0_dotter_E1_C1",
        "T0_dotter_stent_E1_C1",
        "T0_bypass_E1_C1",
        "T0_etalagebenen_E1_C1",
        "T0_TIA_E1_C1",
        "T2_CVA_E3_C10",
        "T2_CVA_E3_C11",
        "T2_CVA_datum_E3_C10",
        "T2_CVA_datum_E3_C11",
        "T2_CVA_type_E3_C10",
        "T2_CVA_type_E3_C11",
        "T2_CVA_type_overig_E3_C10",
        "T2_CVA_type_overig_E3_C11",
        "T2_cardio_E3_C10",
        "T2_cardio_E3_C11",
        "T2_cardio_type_E3_C10",
        "T2_cardio_type_E3_C11",
        "T2_cardio_type_overig_E3_C10",
        "T2_cardio_type_overig_E3_C11",
        "T2_cardio_datum_E3_C10",
        "T2_cardio_datum_E3_C11",
        "T2_1_datum_overlijden_E3_C11",
        "T2_1_oorzaak_overlijden_E3_C11",
        "T4_CVA_E4_C12",
        "T4_CVA_datum_E4_C12",
        "T4_CVA_type_overig_E4_C12",
        "T4_cardio_E4_C12",
        "T4_cardio_type_E4_C12",
        "T4_cardio_type_overig_E4_C12",
        "T4_cardio_datum_E4_C12",
        "T4_1_datum_overlijden_E4_C12",
        "T4_1_oorzaak_overlijden_E4_C12",
    ]
    essential_cols = {"patientID", "T0_CDR_E1_C1", "T2_CDR_E3_C10", "T4_CDR_E4_C12"}
    missing_essential = [c for c in essential_cols if c not in df_fu]
    if missing_essential:
        raise KeyError(f"Essential outcome columns missing from fu dataset: {missing_essential}")
    missing_optional = [c for c in outcome_cols if c not in df_fu]
    if missing_optional:
        LOGGER.warning("Outcome columns missing from fu dataset and will be filled with NaN: %s", missing_optional)

    outcomes = df_fu.reindex(columns=outcome_cols)
    date_cols = [c for c in outcomes.columns if "datum" in c.lower()]
    to_datetime(outcomes, date_cols)

    outcomes.rename(
        columns={
            "T0_CDR_E1_C1": "T0_CDR",
            "T2_CDR_E3_C10": "T2_CDR",
            "T4_CDR_E4_C12": "T4_CDR",
        },
        inplace=True,
    )
    for col in ["T0_CDR", "T2_CDR", "T4_CDR"]:
        if col in outcomes:
            outcomes[col] = pd.to_numeric(outcomes[col], errors="coerce")
    outcomes["T4_CDR"] = map_cdr_values(outcomes.get("T4_CDR", pd.Series(dtype=float, index=outcomes.index)))
    outcomes["T2_CDR"] = map_cdr_values(outcomes.get("T2_CDR", pd.Series(dtype=float, index=outcomes.index)))

    # Coalesce duplicated follow-up columns
    coalesce(outcomes, ["T2_CVA_E3_C10", "T2_CVA_E3_C11"], "T2_CVA")
    coalesce(outcomes, ["T2_CVA_type_E3_C10", "T2_CVA_type_E3_C11"], "T2_CVA_type")
    coalesce(outcomes, ["T2_CVA_datum_E3_C10", "T2_CVA_datum_E3_C11"], "T2_CVA_datum")
    coalesce(outcomes, ["T2_cardio_E3_C10", "T2_cardio_E3_C11"], "T2_cardio")
    coalesce(outcomes, ["T2_cardio_type_E3_C10", "T2_cardio_type_E3_C11"], "T2_cardio_type")
    coalesce(outcomes, ["T2_cardio_type_overig_E3_C10", "T2_cardio_type_overig_E3_C11"], "T2_cardio_type_overig")
    coalesce(outcomes, ["T2_cardio_datum_E3_C10", "T2_cardio_datum_E3_C11"], "T2_cardio_datum")

    # Drop original duplicates
    drop_cols = [
        "T2_CDR_E3_C11",
        "T2_CVA_E3_C10",
        "T2_CVA_E3_C11",
        "T2_CVA_type_E3_C10",
        "T2_CVA_type_E3_C11",
        "T2_CVA_datum_E3_C10",
        "T2_CVA_datum_E3_C11",
        "T2_cardio_E3_C10",
        "T2_cardio_E3_C11",
        "T2_cardio_type_E3_C10",
        "T2_cardio_type_E3_C11",
        "T2_cardio_type_overig_E3_C10",
        "T2_cardio_type_overig_E3_C11",
        "T2_cardio_datum_E3_C10",
        "T2_cardio_datum_E3_C11",
    ]
    outcomes.drop(columns=[c for c in drop_cols if c in outcomes], inplace=True)

    # Stroke events
    t0_cva = pd.to_numeric(outcomes.get("T0_CVA_E1_C1"), errors="coerce")
    outcomes["T0_Event_Stroke"] = np.where(t0_cva.isin([1, 2, 3]), 1, 0)

    def contains_any(series: pd.Series, patterns: Sequence[str]) -> pd.Series:
        pattern = "|".join(patterns)
        return series.fillna("").str.contains(pattern, case=False, regex=True)

    outcomes["T2_Event_Stroke"] = np.where(
        outcomes["T2_CVA"].isin([1, 2])
        | contains_any(outcomes.get("T2_1_oorzaak_overlijden_E3_C11"), ["cva", "herseninfarct", "hersenbloeding"]),
        1,
        0,
    )
    outcomes["T4_Event_Stroke"] = np.where(
        outcomes["T4_CVA_E4_C12"].isin([1, 2])
        | contains_any(outcomes.get("T4_1_oorzaak_overlijden_E4_C12"), ["cva", "herseninfarct", "hersenbloeding"]),
        1,
        0,
    )
    outcomes["Event_Stroke"] = np.where(
        (outcomes["T2_Event_Stroke"] == 1) | (outcomes["T4_Event_Stroke"] == 1),
        1,
        0,
    )

    # MACE definition
    mace_baseline = (
        outcomes["T0_CVA_E1_C1"].isin([1, 2, 3])
        | (outcomes.get("T0_hartinfarct_E1_C1") == 1)
        | (outcomes.get("T0_dotter_E1_C1") == 1)
        | (outcomes.get("T0_dotter_stent_E1_C1") == 1)
        | (outcomes.get("T0_bypass_E1_C1") == 1)
        | (outcomes.get("T0_etalagebenen_E1_C1") == 1)
    )
    outcomes["T0_Event_MACE"] = np.where(mace_baseline, 1, 0)

    def has_event(series):
        if series is None:
            return pd.Series(False, index=outcomes.index)
        if pd.api.types.is_numeric_dtype(series):
            return series.isin([1, 2])
        series_str = series.astype(str).str.strip().str.casefold()
        return series_str.str.startswith("ja")

    mace_t2 = (
        has_event(outcomes.get("T2_CVA"))
        | has_event(outcomes.get("T2_cardio"))
        | contains_any(
            outcomes.get("T2_1_oorzaak_overlijden_E3_C11"),
            ["myocardinfarct", "hersenbloeding", "aneurysma"],
        )
    )
    outcomes["T2_Event_MACE"] = np.where(mace_t2, 1, 0)

    mace_t4 = (
        has_event(outcomes.get("T4_CVA_E4_C12"))
        | has_event(outcomes.get("T4_cardio_E4_C12"))
        | contains_any(
            outcomes.get("T4_1_oorzaak_overlijden_E4_C12"),
            [
                "cva",
                "herseninfarct",
                "vaatlijden",
                "subarach",
                "hartstilstand",
                "cardiac arrest",
                "decompensatio",
                "hartfalen",
                "vasculaire",
                "myocardinfarct",
            ],
        )
    )
    outcomes["T4_Event_MACE"] = np.where(mace_t4, 1, 0)
    outcomes["OUTCOME_MACE"] = np.where(
        (outcomes["T2_Event_MACE"] == 1) | (outcomes["T4_Event_MACE"] == 1),
        1,
        0,
    )

    # Dropout reasons
    dropout_labels = {
        0: "Untraceable",
        1: "Deceased",
        2: "Too Ill",
        3: "Moved to Nursing Home",
        4: "Refusal",
        5: "Other",
    }
    canonical_dropout = {
        "no dropout": "No Dropout",
        "untraceerbaar": "Untraceable",
        "untraceable": "Untraceable",
        "deceased": "Deceased",
        "too ill": "Too Ill",
        "moved to nursing home": "Moved to Nursing Home",
        "refusal": "Refusal",
        "other": "Other",
    }
    for phase in ("T2", "T4"):
        col = f"{phase}_reden_geen_deelname_E3_C11" if phase == "T2" else "T4_reden_geen_deelname_E4_C12"
        new_col = f"{phase}_dropout_reason"
        series = outcomes.get(col)
        if series is None:
            outcomes[new_col] = "No Dropout"
            outcomes[f"{new_col}_norm"] = "no dropout"
            continue
        if pd.api.types.is_numeric_dtype(series):
            mapped = series.map(dropout_labels)
        else:
            mapped = series.replace(dropout_labels)
        filled = mapped.fillna(series).fillna("No Dropout")

        def _translate_dropout(value: str) -> str:
            if not isinstance(value, str):
                return value
            val = value.strip()
            if not val:
                return "No Dropout"
            match = re.match(r"^([0-9])\s*=\s*(.*)$", val)
            if match:
                num_code = int(match.group(1))
                remainder = match.group(2).strip()
                return dropout_labels.get(num_code, canonical_dropout.get(remainder.casefold(), remainder))
            lower = val.casefold()
            replacements = {
                "geen dropout": "No Dropout",
                "geendropout": "No Dropout",
                "no dropout": "No Dropout",
                "ontraceerbaar": "Untraceable",
                "patiënt is overleden": "Deceased",
                "patiënt is te ziek": "Too Ill",
                "patiënt is opgenomen in een verzorgingshuis": "Moved to Nursing Home",
                "patiënt is opgenomen in een verzorgingshuis/verpleeghuis": "Moved to Nursing Home",
                "patiënt is opgenomen in een verzorgingshuis / verpleeghuis": "Moved to Nursing Home",
                "patiënt weigert": "Refusal",
                "deelnemer, naaste en (huis)arts kunnen niet worden getraceerd": "Untraceable",
                "deelnemer kan niet worden getraceerd": "Untraceable",
                "deelnemer is overleden": "Deceased",
                "deelnemer is te ziek": "Too Ill",
                "deelnemer is opgenomen in een verzorgingshuis/verpleeghuis": "Moved to Nursing Home",
                "deelnemer is opgenomen in een verzorgingshuis / verpleeghuis": "Moved to Nursing Home",
                "deelnemer weigert": "Refusal",
                "anders, namelijk": "Other",
                "anders": "Other",
            }
            for key, replacement in replacements.items():
                if lower.startswith(key):
                    return replacement
            return canonical_dropout.get(lower, val)

        translated = filled.apply(_translate_dropout)
        outcomes[new_col] = translated
        outcomes[f"{new_col}_norm"] = translated.astype(str).str.strip().str.casefold()

    outcomes["OUTCOME_CDR_INCREASE"] = np.where(
        (outcomes["T2_CDR"] > outcomes["T0_CDR"])
        | (outcomes["T4_CDR"] > outcomes["T0_CDR"])
        | (outcomes["T4_CDR"] > outcomes["T2_CDR"])
        | (outcomes["T2_dropout_reason"] == "Moved to Nursing Home")
        | (outcomes["T4_dropout_reason"] == "Moved to Nursing Home"),
        1,
        0,
    )

    outcomes.loc[
        outcomes["OUTCOME_CDR_INCREASE"].isna() & (outcomes["T4_CDR"] > outcomes["T0_CDR"]),
        "OUTCOME_CDR_INCREASE",
    ] = 1

    # Convert outcomes into categorical labels with explicit Unobserved state
    norm_t4 = outcomes.get(
        "T4_dropout_reason_norm",
        outcomes["T4_dropout_reason"].astype(str).str.strip().str.casefold(),
    )

    mask_mace_unobserved = (outcomes["OUTCOME_MACE"] == 0) & (norm_t4 != "no dropout")
    outcomes.loc[mask_mace_unobserved, "OUTCOME_MACE"] = np.nan
    outcomes["OUTCOME_MACE"] = (
        outcomes["OUTCOME_MACE"].map({1: "Yes", 0: "No"}).fillna("Unobserved").astype("category")
    )

    mask_cdr_unobserved = outcomes["OUTCOME_CDR_INCREASE"].isna() | (
        (outcomes["OUTCOME_CDR_INCREASE"] == 0) & (norm_t4 != "no dropout")
    )
    outcomes.loc[mask_cdr_unobserved, "OUTCOME_CDR_INCREASE"] = np.nan
    outcomes["OUTCOME_CDR_INCREASE"] = (
        outcomes["OUTCOME_CDR_INCREASE"].map({1: "Yes", 0: "No"}).fillna("Unobserved").astype("category")
    )

    norm_cols = [col for col in outcomes.columns if col.endswith("_dropout_reason_norm")]
    outcomes.drop(columns=norm_cols, inplace=True)

    outcomes_sub = outcomes[["patientID", "T4_dropout_reason", "OUTCOME_MACE", "OUTCOME_CDR_INCREASE"]].copy()

    return outcomes, outcomes_sub

# %% [markdown]
# ## Subset selection and engineered variables
#
# - Filters columns according to `bn_vars` (layered codebook).
# - Adds engineered variables:
#   - `T0_SYS_BP`, `T0_DIAS_BP`
#   - `HV_ICV`, `TBV_ICV`, `CBF`
#   - smoking quantities and `MACE` history.
# - Then harmonises column names to the BN naming conventions.

# %%
# Cell 7 – Subset, harmonisation, and metadata setup

def prepare_subset(df_fu: pd.DataFrame, bn_vars: pd.DataFrame) -> tuple[pd.DataFrame, pd.DataFrame]:
    bn_vars_filter = bn_vars.loc[bn_vars["LAYER"].notna(), ["LAYER", "VARIABLE NAME"]].copy()
    bn_vars_filter.loc[bn_vars_filter["VARIABLE NAME"] == "DROPOUT REASON", "LAYER"] = "L9 – Dropout"

    extra_vars = [
        "patientID",
        "T0_patientengroep_E1_C1",
        "Sex",
        "T0_Age",
        "T0_pTau181",
        "T0_NfL",
        "T0_GFAP",
        "T0_Aβ40",
        "T0_Aβ42",
    ]

    # Always include SCORE2 input columns even if absent from bn_vars.
    # Search df_fu for the right SPSS column names dynamically.
    _score2_keywords = {
        "chol":       ["totaal", "hdl", "ldl"],   # total-chol, HDL, LDL
        "roken":      [],                           # smoking
        "diabetes":   [],                           # diabetes
        "systolisch": [],                           # systolic BP (SYS_BP computed later)
    }
    for kw, sub_kws in _score2_keywords.items():
        matches = [c for c in df_fu.columns if kw in c.lower()]
        if sub_kws:
            matches = [c for c in matches if any(s in c.lower() for s in sub_kws)]
        extra_vars.extend(matches)

    all_cols = pd.Index(df_fu.columns)
    base_names = all_cols.str.replace(r"_E[0-9]+_C[0-9]+$", "", regex=True)
    allowed = bn_vars_filter["VARIABLE NAME"].unique()
    matched_cols = [col for col, base in zip(all_cols, base_names) if base in allowed]
    final_cols = list(dict.fromkeys(extra_vars + matched_cols))
    subset = df_fu.loc[:, [c for c in final_cols if c in df_fu]].copy()

    def safe_mean(cols: Sequence[str]) -> pd.Series:
        present = [subset[c] for c in cols if c in subset]
        if not present:
            return pd.Series(np.nan, index=subset.index)
        return pd.concat(present, axis=1).mean(axis=1, skipna=True)

    subset["T0_SYS_BP"] = safe_mean(["T0_systolisch_a_E1_C1", "T0_systolisch_b_E1_C1"])
    subset["T0_DIAS_BP"] = safe_mean(["T0_Diastolisch_a_E1_C1", "T0_Diastolisch_b_E1_C1"])
    icv = subset.get("T0_q_ic_tissue_total_intracranial_volume_ml")
    if icv is not None:
        subset["T0_HV_ICV"] = (
            safe_mean(
                [
                    "T0_i_ic_gm_Hippocampus_left_volume_ml",
                    "T0_i_ic_gm_Hippocampus_right_volume_ml",
                ]
            )
            * 100
            / icv
        )
        brain = subset.get("T0_q_ic_tissue_total_brain_volume_ml")
        if brain is not None:
            subset["T0_TBV_ICV"] = brain * 100 / icv
    subset["T0_CBF"] = subset.get("T0_i_ic_cbf_GrayMatter_mean_mL100gmin")

    def fill_smoking(primary: str, backup: str) -> pd.Series:
        res = subset.get(primary, pd.Series(np.nan, index=subset.index)).copy()
        backup_series = subset.get(backup)
        if backup_series is not None:
            res = res.fillna(backup_series)
        return res.fillna(0)

    subset["T0_roken_hoeveel_jaar_a_E1_C1"] = fill_smoking(
        "T0_roken_hoeveel_jaar_a_E1_C1", "T0_roken_hoeveel_jaar_b_E1_C1"
    )
    subset["T0_roken_hoeveel_per_dag_a_E1_C1"] = fill_smoking(
        "T0_roken_hoeveel_per_dag_a_E1_C1", "T0_roken_hoeveel_per_dag_b_E1_C1"
    )

    def is_one(col: str) -> pd.Series:
        series = subset.get(col)
        if series is None:
            return pd.Series(False, index=subset.index)
        series = series.fillna(0)
        if pd.api.types.is_numeric_dtype(series):
            return series == 1
        series_str = series.astype(str).str.strip().str.casefold()
        return series_str.isin({"1", "ja", "yes", "true"})

    subset["T0_CAD"] = np.where(
        is_one("T0_bypass_E1_C1") | is_one("T0_dotter_E1_C1") | is_one("T0_hartinfarct_E1_C1"),
        1,
        0,
    )
    subset["T0_PAD"] = np.where(is_one("T0_etalagebenen_E1_C1"), 1, 0)
    subset["MACE"] = np.where((subset["T0_CAD"] == 1) | (subset["T0_PAD"] == 1), 1, 0)

    subset.drop(
        columns=[
            col
            for col in [
                "T0_roken_hoeveel_jaar_b_E1_C1",
                "T0_roken_hoeveel_per_dag_b_E1_C1",
                "T0_etalagebenen_E1_C1",
                "T0_hartinfarct_E1_C1",
                "T0_bypass_E1_C1",
                "T0_dotter_E1_C1",
                "T0_PAD",
                "T0_CAD",
            ]
            if col in subset
        ],
        inplace=True,
    )

    return subset, bn_vars_filter


def harmonise_columns(df_final: pd.DataFrame, bn_vars_filter: pd.DataFrame) -> None:
    bn_vars_filter["LAYER"] = bn_vars_filter["LAYER"].astype(str).str.strip()
    bn_vars_filter["VARIABLE NAME"] = bn_vars_filter["VARIABLE NAME"].str.replace("T0_", "", regex=False)
    df_final.columns = (
        df_final.columns.str.replace("_E1_C1", "", regex=False)
        .str.replace("_E1_C6", "", regex=False)
        .str.replace("T0_", "", regex=False)
        .str.replace("β", "B", regex=False)
        .str.upper()
    )
    bn_vars_filter["VARIABLE NAME"] = (
        bn_vars_filter["VARIABLE NAME"].str.replace("β", "B", regex=False).str.upper()
    )

# %%
# Cell 8 – Extra metadata rows, name mapping, label translations

EXTRA_LAYER_ROWS = [
    ("L2 – Cardiovascular risk factors", "SYS_BP"),
    ("L2 – Cardiovascular risk factors", "DIAS_BP"),
    ("L5 - Imaging markers of neurovascular damage", "HV_ICV"),
    ("L5 - Imaging markers of neurovascular damage", "TBV_ICV"),
    ("L4 – Potential disease process markers", "CBF"),
    ("L8 – Outcomes", "OUTCOME_CDR_INCREASE"),
    ("L9 – Dropout", "DROPOUT REASON"),
    ("L8 – Outcomes", "OUTCOME_MACE"),
    ("L0 – Unmodifiable demographics", "AGE"),
    ("L0 – Unmodifiable demographics", "SEX"),
    ("L4 – Potential disease process markers", "PTAU181"),
    ("L4 – Potential disease process markers", "NFL"),
    ("L4 – Potential disease process markers", "GFAP"),
    ("L6 – Current and previous cardiovascular diagnoses / Vascular interventions", "PATIENTENGROEP"),
    ("L4 – Potential disease process markers", "AB40"),
    ("L4 – Potential disease process markers", "AB42"),
    ("L6 – Current and previous cardiovascular diagnoses / Vascular interventions", "MACE"),
    ("L2 – Cardiovascular risk factors", "SCORE_2"),
]


NAME_MAPPING = {
    "MMSE_TOTAAL": "MINI MENTAL STATE EXAMINATION",
    "STARKSTEIN": "STARKSTEIN SCORE",
    "CDR": "BASELINE CDR",
    "CVA": "STROKE HISTORY",
    "BCS_1": "BIOMARKER SCORE 1",
    "BCS_2": "BIOMARKER SCORE 2",
    "NEURORAD_SVD_SCORE": "SMALL VESSEL DISEASE SCORE",
    "HV_ICV": "HIPPOCAMPUS/INTRACRANIAL VOLUME",
    "TBV_ICV": "BRAIN/INTRACRANIAL VOLUME",
    "CBF": "CEREBRAL BLOOD FLOW",
    "EVENT_MACE": "OUTCOME_MACE",
    "CDR_INCR": "OUTCOME_CDR_INCREASE",
    "T4_DROPOUT_REASON": "DROPOUT REASON",
    "AGE": "AGE",
    "SEX": "SEX",
    "PTAU181": "PTAU181",
    "NFL": "NFL",
    "GFAP": "GFAP",
    "PATIENTENGROEP": "PATIENT GROUP",
    "MACE": "ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY",
    "SCORE_2": "VASCULAR RISK SCORE",
}


LABEL_TRANSLATION: Mapping[str, Mapping[str, str]] = {
    "STROKE HISTORY": {
        "Ja, hersenbloeding": "Yes, hemorrhagic stroke",
        "Ja, herseninfarct": "Yes, ischemic stroke",
        "Ja, type onbekend": "Yes, type unknown",
        "Nee": "No",
    },
    "PATIENT GROUP": {
        "Carotid occlusive disease": "Carotid occlusive disease",
        "Controle": "Reference",
        "Hartfalen": "Heart failure",
        "Vascular cognitive impairment": "Vascular cognitive impairment",
    },
    "ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY": {"0": "No", "1": "Yes"},
}

BASELINE_CDR_CATEGORIES = ["0", "0.5", "1", "1.5", "2", "3"]


def enforce_domain_categories(df: pd.DataFrame) -> None:
    if "BASELINE CDR" in df:
        def _format_cdr(value):
            if pd.isna(value):
                return pd.NA
            try:
                numeric = float(value)
            except (TypeError, ValueError):
                return str(value)
            mapping = {0.0: "0", 0.5: "0.5", 1.0: "1", 1.5: "1.5", 2.0: "2", 3.0: "3"}
            return mapping.get(numeric, str(numeric))

        formatted = df["BASELINE CDR"].apply(_format_cdr)
        df["BASELINE CDR"] = pd.Categorical(formatted, categories=BASELINE_CDR_CATEGORIES, ordered=True)

    for column in ["STROKE HISTORY", "PATIENT GROUP", "SEX"]:
        if column in df:
            series = df[column].astype("string")
            df[column] = pd.Categorical(series, ordered=False)

    if "ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY" in df:
        series = df["ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY"].astype("string").str.strip()
        mapping = {
            "0": "No",
            "1": "Yes",
            "No": "No",
            "Yes": "Yes",
        }
        translated = series.replace(mapping)
        df["ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY"] = pd.Categorical(
            translated,
            categories=["No", "Yes"],
            ordered=False,
        )


def normalise_string_categories(df: pd.DataFrame) -> pd.DataFrame:
    for col in df.select_dtypes(include="object"):
        df[col] = df[col].astype(str).str.strip()
    return df


def translate_labels(df: pd.DataFrame) -> pd.DataFrame:
    for column, mapping in LABEL_TRANSLATION.items():
        if column in df:
            series = df[column].astype(str)
            lower = series.str.strip().str.casefold()
            normalized_mapping = {key.casefold(): value for key, value in mapping.items()}
            mapped = lower.map(normalized_mapping)
            df[column] = series.where(mapped.isna(), mapped)
            df[column] = df[column].astype("category")
    return df

# %% [markdown]
# ## Imputation and baseline tables
#
# - `impute_dataframe`: IterativeImputer for numeric, mode imputation for categorical.
# - Baseline table helpers:
#   - Group by patient group.
#   - Summarise medians/IQR and percentages.

# %%
# Cell 9 – Imputation and baseline table helpers

def impute_dataframe(df: pd.DataFrame, seed: int) -> pd.DataFrame:
    numeric = df.select_dtypes(include=["number"]).copy()
    other = df.select_dtypes(exclude=["number"]).copy()

    imputer = IterativeImputer(random_state=seed, sample_posterior=False)
    if not numeric.empty:
        numeric = pd.DataFrame(imputer.fit_transform(numeric), columns=numeric.columns, index=df.index)

    for col in other.columns:
        series = other[col]
        if series.isnull().any():
            if pd.api.types.is_categorical_dtype(series):
                modes = series.mode(dropna=True)
                fill_value = modes.iloc[0] if not modes.empty else series.cat.categories[0]
                if fill_value not in series.cat.categories:
                    series = series.cat.add_categories([fill_value])
                series = series.fillna(fill_value)
            else:
                modes = series.mode(dropna=True)
                fill_value = modes.iloc[0] if not modes.empty else ""
                series = series.fillna(fill_value)
            other[col] = series

    combined = pd.concat([numeric, other], axis=1)
    return combined[df.columns]


BASELINE_GROUP_ORDER = [
    "Carotid occlusive disease",
    "Heart failure",
    "Vascular cognitive impairment",
    "Reference",
]

# Each entry: (display label, list of casefold prefixes that match the category).
# Prefix matching handles Dutch label variations like "Ja, met leefstijladvies"
# and "Ja, Met Leefstijladvies" (after title-casing) equally.
DIABETES_CATEGORY_LABELS = [
    ("Yes, with lifestyle advice",    ["ja, met leefstijl"]),
    ("Yes, with oral antidiabetics",  ["ja, met orale", "yes, with oral"]),
    ("Yes, with insulin",             ["ja, met insuline", "yes, with insulin"]),
    ("No",                            ["nee", "no", "geen diabetes"]),
]

SMOKING_CATEGORY_LABELS = [
    ("Yes",         ["yes", "ja"]),
    ("No",          ["no", "nee", "never", "nooit"]),
    ("Not anymore", ["not anymore", "niet meer", "gestopt", "ex-roker", "ex roker", "ex-smoker", "former", "quit"]),
]

CVA_CATEGORY_LABELS = [
    ("Yes, hemorrhage",  ["yes, hemorrhage", "yes, haemorrhage", "yes, hemorrhagic stroke"]),
    ("Yes, stroke",      ["yes, stroke", "yes, ischemic stroke"]),
    ("Yes, type unknown",["yes, type unknown"]),
    ("No",               ["no"]),
]

PATIENT_GROUP_CATEGORY_LABELS = [
    ("Carotid occlusive disease",    ["carotid occlusive disease"]),
    ("Heart failure",                ["heart failure"]),
    ("Vascular cognitive impairment",["vascular cognitive impairment"]),
    ("Reference",                    ["reference", "controle"]),
]


def _normalize_label(value: str | float | int | None) -> str | None:
    if value is None or (isinstance(value, str) and value.strip() == ""):
        return None
    if isinstance(value, (float, int)) and pd.isna(value):
        return None
    s = str(value).strip().casefold()
    return None if s in {"nan", "none", "<na>"} else s


def _format_median_iqr(series: pd.Series | None) -> str:
    if series is None:
        return "NA"
    numeric = pd.to_numeric(series, errors="coerce").dropna()
    if numeric.empty:
        return "NA"
    q1 = numeric.quantile(0.25)
    median = numeric.median()
    q3 = numeric.quantile(0.75)
    return f"{median:.2f} [{q1:.2f}, {q3:.2f}]"


def _format_count_pct(series: pd.Series | None, targets: Sequence[str]) -> str:
    """Count rows whose casefolded value starts with any of the target prefixes."""
    if series is None:
        return "NA"
    normalized = (
        pd.Series(series)
        .apply(_normalize_label)
        .dropna()
    )
    if normalized.empty:
        return "NA"
    target_prefixes = [_normalize_label(t) for t in targets if t]
    target_prefixes = [p for p in target_prefixes if p]
    count = normalized.apply(
        lambda v: any(v.startswith(p) for p in target_prefixes)
    ).sum()
    pct = count / len(normalized) * 100
    return f"{int(count)} ({pct:.1f})"


def _build_group_sequence(df: pd.DataFrame, group_col: str) -> list[tuple[str, pd.DataFrame]]:
    groups: list[tuple[str, pd.DataFrame]] = [("Overall", df)]
    if group_col not in df:
        LOGGER.warning("Baseline table: column %s is missing", group_col)
        return groups
    present_values = df[group_col].dropna()
    added: set[str] = set()
    for label in BASELINE_GROUP_ORDER:
        mask = present_values == label
        if mask.any():
            groups.append((label, df[df[group_col] == label]))
            added.add(label)
    for value in present_values.unique():
        if value in added:
            continue
        groups.append((value, df[df[group_col] == value]))
        added.add(value)
    return groups


def _add_category_rows(
    rows: list[dict[str, str]],
    groups: list[tuple[str, pd.DataFrame]],
    metric_label: str,
    column: str,
    categories: Sequence[tuple[str, Sequence[str]]],
) -> None:
    for display_label, target_values in categories:
        row = {"Metric": metric_label, "Submetric": display_label}
        for group_name, group_df in groups:
            row[group_name] = _format_count_pct(group_df.get(column), target_values)
        rows.append(row)


def build_baseline_table_by_group(df: pd.DataFrame) -> pd.DataFrame:
    """Return baseline characteristics table per patient group."""
    working = df.copy()
    working.rename(columns=NAME_MAPPING, inplace=True)
    working = normalise_string_categories(working)
    working = translate_labels(working)

    group_col = "PATIENT GROUP" if "PATIENT GROUP" in working else "PATIENTENGROEP"
    groups = _build_group_sequence(working, group_col)
    rows: list[dict[str, str]] = []

    def add_simple_row(metric: str, func, submetric: str = "") -> None:
        row = {"Metric": metric, "Submetric": submetric}
        for group_name, group_df in groups:
            row[group_name] = func(group_df)
        rows.append(row)

    add_simple_row("n", lambda gdf: f"{len(gdf)}")
    add_simple_row("Age (median [IQR])", lambda gdf: _format_median_iqr(gdf.get("AGE")))
    add_simple_row(
        "Male sex (%)",
        lambda gdf: _format_count_pct(gdf.get("SEX"), ["male", "man", "m"]),
    )

    _add_category_rows(rows, groups, "Diabetes (%)", "DIABETES", DIABETES_CATEGORY_LABELS)
    _add_category_rows(rows, groups, "Smoking (%)", "ROKEN", SMOKING_CATEGORY_LABELS)

    add_simple_row(
        "Systolic blood pressure (median [IQR])",
        lambda gdf: _format_median_iqr(gdf.get("SYS_BP")),
    )
    add_simple_row(
        "Low-density lipoprotein cholesterol (median [IQR])",
        lambda gdf: _format_median_iqr(gdf.get("CHOLESTEROL_LDL")),
    )
    add_simple_row(
        "Systematic Coronary Risk Evaluation score (median [IQR])",
        lambda gdf: _format_median_iqr(gdf.get("SCORE_2")),
    )
    add_simple_row(
        "Blood pressure medication = No (%)",
        lambda gdf: _format_count_pct(gdf.get("BLOEDDRUK_MEDICATIE"), ["no", "nee"]),
    )
    add_simple_row(
        "Transient Ischaemic Attack = No (%)",
        lambda gdf: _format_count_pct(gdf.get("TIA"), ["no", "nee"]),
    )

    _add_category_rows(
        rows,
        groups,
        "Cerebrovascular Accident (%)",
        "STROKE HISTORY",
        CVA_CATEGORY_LABELS,
    )
    _add_category_rows(
        rows,
        groups,
        "Patient group (%)",
        group_col,
        PATIENT_GROUP_CATEGORY_LABELS,
    )

    table = pd.DataFrame(rows)
    group_names = [name for name, _ in groups]
    ordered_cols = ["Metric", "Submetric"] + group_names
    return table.loc[:, ordered_cols]

# %% [markdown]
# ## Run the preprocessing pipeline step by step
#
# From here on, we **run** the pipeline, approximating the original `preprocess(config)` function but in explicit notebook cells so you can inspect intermediate outputs.

# %%
# Cell 10 – Load raw data

LOGGER.info("Loading raw tables from %s", config.raw_dir)

df_bl, meta_bl = read_sav(config.raw_dir / "df.sav")
df_bl = apply_value_labels(df_bl, meta_bl)

df_fu, meta_fu = read_sav(config.raw_dir / "fu_2.sav")
df_fu = apply_value_labels(df_fu, meta_fu)

cs_1 = pd.read_excel(config.raw_dir / "compound_score.xlsx")
cs_2 = pd.read_csv(config.raw_dir / "cs_cleaned_final.csv", sep=";", decimal=",")

for frame in (cs_1, cs_2):
    if "patientID" in frame:
        frame["patientID"] = pd.to_numeric(frame["patientID"], errors="coerce")

df_fu = df_fu.merge(cs_1, how="left", on="patientID").merge(cs_2, how="left", on="patientID")

LOGGER.info("df_bl shape: %s", df_bl.shape)
LOGGER.info("df_fu shape (with compound scores): %s", df_fu.shape)
# Out:
# INFO Loading raw tables from <PROJECT_ROOT>/04_BAYESIAN_OUTPUT/data
# INFO df_bl shape: (559, 1346)
# INFO df_fu shape (with compound scores): (566, 3545)

# %%
# Explore dropout-related columns in df_fu
dropout_cols = [col for col in df_fu.columns if any(
    kw in col.lower() for kw in ['reden', 'dropout', 'anders', 'deelname']
)]

print(f"Dropout-related columns ({len(dropout_cols)}):")
for col in dropout_cols:
    n_filled = df_fu[col].notna().sum()
    print(f"  {col}  (n filled = {n_filled})")

# Show the free-text 'Other' columns — typically contain 'anders' in the name
other_text_cols = [col for col in dropout_cols if 'anders' in col.lower()]
print(f"\nFree-text 'Other' columns ({len(other_text_cols)}):")
for col in other_text_cols:
    print(f"\n── {col} ──")
    vals = df_fu[col].dropna().astype(str).str.strip()
    vals = vals[vals != '']
    print(vals.value_counts().to_string())
# Out:
# Dropout-related columns (42):
#   T0_deelnameonderzoek_therapeutische_interventies_E1_C1  (n filled = 566)
#   T0_redenbloedafnamenietgelukt_E1_C1  (n filled = 566)
#   T0_redenbloedbuizennietvol_E1_C1  (n filled = 566)
#   T0_relatie_MZ_anders_E1_C1  (n filled = 566)
#   T0_4m_hulpmiddel_anders_E1_C1  (n filled = 566)
#   T0_longaandoening_anders_E1_C1  (n filled = 566)
#   T0_ECG_reden_nietgemaakt_E1_C1  (n filled = 566)
#   T0_MRI_software_anders_E1_C1  (n filled = 566)
#   T0_hartf_ritme_anders_E1_C1  (n filled = 566)
#   T0_hartf_Myo_anders_E1_C1  (n filled = 566)
#   T0_hartf_PTCA_anders_a_E1_C1  (n filled = 566)
#   T0_hartf_PTCA_anders_b_E1_C1  (n filled = 566)
#   T0_toeval_spec_anders_E1_C1  (n filled = 566)
#   T1_relatie_MZ_anders_E2_C8  (n filled = 566)
#   T1_reden_geen_deelname_E2_C9  (n filled = 32)
#   T1_4_reden_weigeren_E2_C9  (n filled = 566)
#   T1_5_anders_E2_C9  (n filled = 566)
#   T2_redenbloedafnamenietgelukt_E3_C10  (n filled = 566)
#   T2_redenbloedbuizennietvol_E3_C10  (n filled = 566)
#   T2_relatie_MZ_anders_E3_C10  (n filled = 566)
#   T2_4m_hulpmiddel_anders_E3_C10  (n filled = 566)
#   T2_ziekenhuis_reden_E3_C10  (n filled = 566)
#   T2_dementie_anders_E3_C10  (n filled = 566)
#   T2_letsel_anders_nl_E3_C10  (n filled = 566)
#   T2_ECG_reden_nietgemaakt_E3_C10  (n filled = 566)
#   T2_MRI_geenMRI_reden_E3_C10  (n filled = 566)
#   T2_MRI_software_anders_E3_C10  (n filled = 566)
#   T2_hartf_ritme_anders_E3_C10  (n filled = 566)
#   T2_hartf_Myo_anders_E3_C10  (n filled = 566)
#   T2_hartf_PTCA_anders_a_E3_C10  (n filled = 566)
#   T2_hartf_PTCA_anders_b_E3_C10  (n filled = 566)
#   T2_toeval_spec_anders_E3_C10  (n filled = 566)
#   T2_reden_geen_deelname_E3_C11  (n filled = 181)
#   T2_4_reden_weigeren_E3_C11  (n filled = 566)
#   T2_5_anders_E3_C11  (n filled = 566)
#   T2_ziekenhuis_reden_E3_C11  (n filled = 566)
#   T4_reden_geen_deelname_E4_C12  (n filled = 280)
#   T4_4_reden_weigeren_E4_C12  (n filled = 566)
#   T4_5_anders_E4_C12  (n filled = 566)
#   T4_ziekenhuis_reden_E4_C12  (n filled = 566)
#   T4_dementie_anders_E4_C12  (n filled = 566)
#   T4_reden_geen_TICSM_E4_C12  (n filled = 4)
#
# Free-text 'Other' columns (24):
#
# ── T0_relatie_MZ_anders_E1_C1 ──
# T0_relatie_MZ_anders_E1_C1
# niet aanwezig                              5
# goede vriendin                             3
# Niemand mee                                1
# nichtje                                    1
# geen                                       1
# partner met VCI van gezond proefpersoon    1
# maatje, goede kennis                       1
# buurman                                    1
#
# ── T0_4m_hulpmiddel_anders_E1_C1 ──
# T0_4m_hulpmiddel_anders_E1_C1
# Stokken. (10 jr geleden bovenbeenamputatie ondergaan.)    1
# Stok maar test zonder stok gelopen                        1
#
# ── T0_longaandoening_anders_E1_C1 ──
# T0_longaandoening_anders_E1_C1
# Astma                                                 9
# longontsteking                                        8
# longembolie                                           4
# bronchitis                                            3
# astma                                                 3
# Bronchitis                                            2
# Longontsteking                                        2
# Pneumonie                                             1
# weet dhr niet meer                                    1
# longembolieen en longonstekingen                      1
# Tuberculose op 6 jarige leeftijd                      1
# Bronchitis op kinderleeftijd                          1
# Lichte longontsteking najaar 2016                     1
# Longembolie                                           1
# Astma v.a.2016                                        1
# Verminderde longcapaciteit, geen diagnose             1
# Astma, COPD en longemfyseem.                          1
# Actuut longvirus op 30-jarige leeftijd                1
# 3 tal pneumonieen                                     1
# sarcoidose                                            1
# Chronische bronchitis                                 1
# TBC op 1 1/2 jarige leeftijd                          1
# zware longontsteking dit jaar. Pufjes nu gestopt.     1
# astmatische bronchitis                                1
# longfybrose en 3x longembolie gehad                   1
# hyperreactieve longen na niet onderkende coeliakie    1
# astmatische bronchitis sinds 14/15 jr oud             1
# bronchitis van 0e tot 14 jr                           1
# 3x longontsteking gehad                               1
# longonsteking 1x                                      1
# allergische astma                                     1
# BOOP, gevolg bestraling                               1
# Astmatische bronchitis                                1
# astma bronchiale                                      1
# longfibrose                                           1
# ingekapseld TBC '60                                   1
# astma bronchiale, pneumonie                           1
# pleuritis                                             1
# hyperreactieve luchtwegen                             1
# longontsteking op jeugd leeftijd                      1
# pneumothorax rec                                      1
# pneumonie                                             1
# pulmonale hypertensie                                 1
# longontsteking 2 maanden geleden wv AB                1
# longontsteking feb 2015                               1
# Longembolie 2013                                      1
# 2014 longembolie bzd                                  1
# astma kinderleeftijd tot 10 jaar geleden              1
# verdrinking 2014                                      1
# tuberculose                                           1
# asthmatische bronchitis op kinderleeftijd             1
# astma bronchiale + COPD                               1
# Astma / bronchitis                                    1
# longonsteking                                         1
# astma cardiale                                        1
# Longkanker/asbestose                                  1
# Longonsteking 1x per jaar                             1
#
# ── T0_MRI_software_anders_E1_C1 ──
# T0_MRI_software_anders_E1_C1
# nvt    1
#
# ── T0_hartf_ritme_anders_E1_C1 ──
# T0_hartf_ritme_anders_E1_C1
# ventrikelfibrilleren                                        2
# VF bij infarct '07                                          1
# AV-nodale re-entry tachycardie (2006)                       1
# vf                                                          1
# accessoire bundel (WPW) waarvoor ablatie                    1
# Premature Venticulaire complexen wv Sotalol (dec 2013)      1
# Ventricaulaire aritmie 1993, geen nadere gegevens bekend    1
# premature ventriculaire complexen                           1
# Sinustachycardie                                            1
# 2009 NSVT's op holter                                       1
# non sustained VT                                            1
#
# ── T0_hartf_Myo_anders_E1_C1 ──
# T0_hartf_Myo_anders_E1_C1
# anterior                                      3
# inferior                                      3
# anterolateraal                                3
# inferolateraal                                2
# apicaal                                       1
# en apicaal                                    1
# 1996 infarct waar?? en CABG                   1
# inferolateraal infarct                        1
# antero-lateraal                               1
# infero-lateraal                               1
# anterior-posterior                            1
# basaal apicaal                                1
# Voorwandinfarct                               1
# infero-apicaak, lateraal en antero-septaal    1
# Anterolateraal                                1
# localisatie onbekend                          1
# Voorwandinfarct in 1997 en 2010               1
# Antero                                        1
#
# ── T0_hartf_PTCA_anders_a_E1_C1 ──
# T0_hartf_PTCA_anders_a_E1_C1
# culprit Hoofdstam, LAD en CX    1
# IM                              1
# RCA en MO                       1
# LAD (2x DES) en RCA (5x DES)    1
# LAD, RCA, MO                    1
# PCI venegraft met 3x DES        1
#
# ── T0_hartf_PTCA_anders_b_E1_C1 ──
# T0_hartf_PTCA_anders_b_E1_C1
# Hoofdstam (1x), LAD (2x) en CX (1x)    1
# RPL                                    1
#
# ── T0_toeval_spec_anders_E1_C1 ──
# T0_toeval_spec_anders_E1_C1
# anamnese                                      4
# bloeddrukmeting                               3
# Bloeddruk                                     1
# sinds maanden moe, kortademig, POBklachten    1
# laesie long                                   1
# anamnetisch                                   1
# bloeddrukmetingen                             1
#
# ── T1_relatie_MZ_anders_E2_C8 ──
# T1_relatie_MZ_anders_E2_C8
# vriendin                    2
# partner en schoondochter    1
#
# ── T1_5_anders_E2_C9 ──
# T1_5_anders_E2_C9
# vanuit het UMC is dhr. niet benaderd voor FU1, omdat studie afgerond is                                                                                 4
# Mevr. heeft een depressie en mogelijke stemmingsproblemen. Vooralsnog niet includeren voor FU. Tugba geeft aan als/of dat alsnog gedaan moet worden.    1
# Geen vervolg deelname HBC omdat baseline-MRI vanwege obesitas niet op 3 Tesla is uitgevoerd (= reden voor exclusie).                                    1
# Geen vervolg deelname HBC vanwege atriumfibrilleren (=toevalsbevinding; reden voor exclusie)                                                            1
# Uitgevallen op Baseline. (exclusie vanwege ontbreken van MRI door claustrofobie).                                                                       1
# Geexcludeerd bij baseline ivm claustrofobie.                                                                                                            1
# heeft knie-operatie ondergaan, mag niet autorijden                                                                                                      1
# vanuit het UMC is mw. niet benaderd voor FU1, omdat studie afgerond is                                                                                  1
# mw. is niet benaderd voor FU1, omdat einddatum van studie eerder is bereikt                                                                             1
#
# ── T2_relatie_MZ_anders_E3_C10 ──
# T2_relatie_MZ_anders_E3_C10
# zwager                         1
# vriendin (wonen niet samen)    1
#
# ── T2_4m_hulpmiddel_anders_E3_C10 ──
# T2_4m_hulpmiddel_anders_E3_C10
# Kunstbeen (Rechts)    1
#
# ── T2_dementie_anders_E3_C10 ──
# T2_dementie_anders_E3_C10
# mixed AD/VaD    1
#
# ── T2_letsel_anders_nl_E3_C10 ──
# T2_letsel_anders_nl_E3_C10
# schaafwonden                                                                                                  2
# gebroken knieschijf                                                                                           1
# enkelfractuur/bot gescheurd                                                                                   1
# Wond aan scheenbeen.                                                                                          1
# Zware kneuzing stuitje-gebied, gekneusde ribben, vinger en rug                                                1
# Gekneuse ribben                                                                                               1
# Ernstige kneuzingen                                                                                           1
# 4 gebroken ribben                                                                                             1
# blauwe knie/heup                                                                                              1
# pijnlijke elleboog, nu nog steeds pijn                                                                        1
# blauwe plekken en huidbeschadiging                                                                            1
# kneuzing van ribben                                                                                           1
# Gebitschade                                                                                                   1
# rode plekken op knieën en handen                                                                              1
# schaafplekken heup en wond been                                                                               1
# bloeduitstroting in linker heup                                                                               1
# ribfractuur (gevallen met fiets)                                                                              1
# schaafwond li-knie                                                                                            1
# zomer 2018 op knieën gevallen waarvoor hechtingen. op SEH staphylokok opgelopen, waarvoor spalk en AB geha    1
# schaafwond li-knie en heup. Gekneusde schouder                                                                1
# gekneusde ribben                                                                                              1
# Geschaafde enkel.                                                                                             1
# aangezichtsletsel                                                                                             1
# schouderblessure (geen fractuur)                                                                              1
# Pijnlijke ribben                                                                                              1
# knie/been links.                                                                                              1
# scheenbeen zwaar gekneusd + wond                                                                              1
# Kniewond                                                                                                      1
# Opgezette en pijnlijke  knie                                                                                  1
# Knie, heup, schouder. Geen fracturen, wel kneuzingen en schaafwonden                                          1
# Schaafwonden op verschillende plekken. Is gevallen met de fiets                                               1
# Dikke knie en snee in knie                                                                                    1
# 2x gekneusde ribben, 1x gezwollen knie                                                                        1
# Onder de knie, gevoelige plek                                                                                 1
# Knie beschadigd                                                                                               1
# Ribben gekneusd                                                                                               1
# Wond bovenbeen                                                                                                1
# Schaafwonden in gezicht                                                                                       1
# Knie dik en schaafwonden                                                                                      1
# Wond aan muis van de hand en gescheurde Quadriceps waarvoor operatie                                          1
# Pijnlijke schouder, geen breuk, kon daarna verder fietsen.                                                    1
# hematomen geen breuken                                                                                        1
# Na val last van heup.                                                                                         1
# peesruptuur schouder                                                                                          1
# tussenribspieren pijnlijk                                                                                     1
#
# ── T2_MRI_software_anders_E3_C10 ──
# T2_MRI_software_anders_E3_C10
# vanwege ICD implantatie    1
#
# ── T2_hartf_ritme_anders_E3_C10 ──
# T2_hartf_ritme_anders_E3_C10
# multifocale tachycardie                                    1
# Av block 2e gr. Mobitz II                                  1
# AV nodale re-entry tachycardie                             1
# Ventriculaire aritmie 1993, geen nadere gegevens bekend    1
# 19-1-2009 non sustained VT's op holter                     1
#
# ── T2_hartf_Myo_anders_E3_C10 ──
# T2_hartf_Myo_anders_E3_C10
# inferior                                       2
# Voorwandinfarct 1997 en 2010                   1
# Inferior infarct,ws oud, gemeld op ECG 2019    1
# subendocariaal in 2000                         1
# Voorwandinfarct                                1
# inferolateraal                                 1
# 1-1-1996; myocardinfarct+ CABG                 1
#
# ── T2_hartf_PTCA_anders_a_E3_C10 ──
# T2_hartf_PTCA_anders_a_E3_C10
# IM                             1
# PCI venegraft met 3x stents    1
#
# ── T2_hartf_PTCA_anders_b_E3_C10 ──
# T2_hartf_PTCA_anders_b_E3_C10
# LAD, RCA en MO    1
#
# ── T2_toeval_spec_anders_E3_C10 ──
# T2_toeval_spec_anders_E3_C10
# anamnese         5
# echo             1
# MRI hart         1
# vragenlijst      1
# vragenlijsten    1
#
# ── T2_5_anders_E3_C11 ──
# T2_5_anders_E3_C11
# TC i.v.m afronden onderzoek                                                                                                                                                                                                                                                                                                                                                                                              15
# TC i.v.m afronden studie                                                                                                                                                                                                                                                                                                                                                                                                 14
# Uitgevallen op FU1.                                                                                                                                                                                                                                                                                                                                                                                                       6
# uitgevallen bij FU1                                                                                                                                                                                                                                                                                                                                                                                                       5
# afronden studie                                                                                                                                                                                                                                                                                                                                                                                                           5
# deelnemer is niet benaderd voor FU2, omdat studie afgerond is                                                                                                                                                                                                                                                                                                                                                             3
# uitgevallen op FU1 (overlijden)                                                                                                                                                                                                                                                                                                                                                                                           1
# deelnemer is door onbekende reden destijds niet opgeroepen voor follow-up                                                                                                                                                                                                                                                                                                                                                 1
# TC i.v.m einde studie                                                                                                                                                                                                                                                                                                                                                                                                     1
# FU2 geen deelname interview niet meer gelukt voor einde studie.                                                                                                                                                                                                                                                                                                                                                           1
# deelnemer is uitgevallen tijdens baseline                                                                                                                                                                                                                                                                                                                                                                                 1
# Pacemaker gekregen, kan niet onder de MRI.                                                                                                                                                                                                                                                                                                                                                                                1
# Geen geschikte kandidaat FU2 ivm toevalsbevinding bij de baseline                                                                                                                                                                                                                                                                                                                                                         1
# geen vervoer                                                                                                                                                                                                                                                                                                                                                                                                              1
# we krijgen dhr. niet te pakken na herhaaldelijk geprobeerd te bellen                                                                                                                                                                                                                                                                                                                                                      1
# deelnemer is niet benaderd voor FU2, omdat studie is afgerond                                                                                                                                                                                                                                                                                                                                                             1
# deelnemer is niet benaderd voor deelname aan FU2, omdat studie is afgerond                                                                                                                                                                                                                                                                                                                                                1
# studie is al afgerond                                                                                                                                                                                                                                                                                                                                                                                                     1
# FU2 is nog niet van toepassing                                                                                                                                                                                                                                                                                                                                                                                            1
# Uitgevallen op Baseline. (Exclusie vanwege ontbreken van MRI door claustrofobie).                                                                                                                                                                                                                                                                                                                                         1
# Reden onbekend.                                                                                                                                                                                                                                                                                                                                                                                                           1
# Patiënt is verhuist naar het buitenland.                                                                                                                                                                                                                                                                                                                                                                                  1
# Teveel aan het hoofd door verhuizing e.d.                                                                                                                                                                                                                                                                                                                                                                                 1
# deelnemer overleden voor FU1                                                                                                                                                                                                                                                                                                                                                                                              1
# deelnemer weigerde deelname reeds bij FU1                                                                                                                                                                                                                                                                                                                                                                                 1
# deelnemer had een afspraak op 15-10-2019 maar is niet gekomen. Daarna geen contact meer verkregen.                                                                                                                                                                                                                                                                                                                        1
# Te belastend. Deelnemer is heel langzaam aan het revalideren na val/heup operatie                                                                                                                                                                                                                                                                                                                                         1
# In het afgelopen jaar verschillende keren contact gehad. Dhr voelde zich niet goed, is opgenomen geweest en begint zich nu pas weer wat beter te voelen. Kon het niet opbrengen voor het onderzoek naar het LUMC te komen.                                                                                                                                                                                                1
# Informed consent is na baseline MRI ingetrokken, ivm ziekte. Zie baseline informatie                                                                                                                                                                                                                                                                                                                                      1
# Deelnemer wil perse na het werk (in het LUMC. Op ma, woe of vrijdag na 18.00 uur. Is niet te plannen qua MRI. Gezien de problemen bij de planning bij baseline besloten tot geen follow-up                                                                                                                                                                                                                                1
# TC i.v.m afronden studie.                                                                                                                                                                                                                                                                                                                                                                                                 1
# Heeft sinds 1 jaar de diagnose COPD, werkt hard om uithoudingsvermogen te verbeteren. Kan/wil de follow up van de Hart-Brein Studie er niet bij doen. En heeft sinds kort een klikgebit met magneetjes                                                                                                                                                                                                                    1
# Lukt niet om een afspraak te maken. Heeft 1 vrije dag in de week en gaat dan naar de hartrevalidatie. Is te vermoeiend om ook ons onderzoek op die dag erbij te doen.                                                                                                                                                                                                                                                     1
# Voelt zich niet goed. Is depressief.Ziet de meerwaarde van nog een bezoek niet in. Is ook te vermoeiend.                                                                                                                                                                                                                                                                                                                  1
# Teveel in het medische circuit op dit moment, kan het er niet bij hebben. Note: Wil over 2 jaar best gebeld worden.                                                                                                                                                                                                                                                                                                       1
# Verschillende malen gebeld. 26-04 Nu ziek, heel benauwd Antibiotica. Wil in principe nog wel een keer meedoen. Over 1 maand opnieuw bellen. 12-07 HA gebeld, dhr is opgeknapt en kan gebeld worden. Dhr zelf gesproken, twijfelt over deelname. Eind juli nogmaals bellen en beslissen. Aug 2019 Toch besloten dat het te inspannend is om nog een keer mee te doen. Vindt het wel jammer. Evt wel de telefonische FU     1
# Uitgevallen op FU1                                                                                                                                                                                                                                                                                                                                                                                                        1
# FU1 is nog niet van toepassing                                                                                                                                                                                                                                                                                                                                                                                            1
#
# ── T4_5_anders_E4_C12 ──
# T4_5_anders_E4_C12
# Deelnemer heeft PIF/ICF niet geretourneerd.                                                                                                                                                                                                                                                       28
# Eerder uitgevallen.                                                                                                                                                                                                                                                                               27
# Geen FU2, nu geen reactie op uitnodiging LTM                                                                                                                                                                                                                                                       6
# Deelnemer heeft wel ICF geretourneerd, maar geen gehoor voor afspraak telefonisch interview. Missed i.v.m. einde van de studie.                                                                                                                                                                    2
# Deelnemer heeft PIF/IC niet geretourneerd.                                                                                                                                                                                                                                                         2
# HBC ICF niet ingevuld voor benadering voor toekomstige studies (= geen benadering voor LTM FU)                                                                                                                                                                                                     2
# Participant heeft op baseline-toestemmingsformulier aangegeven niet te willen worden benaderd voor volgend wetenschappelijk onderzoek.                                                                                                                                                             2
# Contact gestaakt: participant heeft toestemmingsformulier niet geretourneerd en is niet telefonisch bereikbaar.                                                                                                                                                                                    2
# Heeft een burnout. Zou zelf contact opnemen als hij toe was aan het interview maar heeft dat niet gedaan.                                                                                                                                                                                          1
# Deelnemer na FU2 niet meer kunnen bereiken voor navraag. Op basis van informatie in EPD (meneer heeft hersenletsel en woont nu begeleid) niet benaderd voor LTM FU.                                                                                                                                1
# Echtgenoot recent overleden. Hoofd staat er niet naar.                                                                                                                                                                                                                                             1
# Niet benaderd na vervelend contact voor FU 2. Kwam niet opdagen.                                                                                                                                                                                                                                   1
# Geen FU2. Wel PIF gestuurd, geen reactie. Niet nagebeld                                                                                                                                                                                                                                            1
# Geen FU2, geen reactie op uitnodiging LTM. Nog wel in leven vlgs huisarts                                                                                                                                                                                                                          1
# IC-procedure succesvol doorlopen, maar niet bereikbaar voor belafspraak.                                                                                                                                                                                                                           1
# Door omstandigheden niet op tijd kunnen benaderen.                                                                                                                                                                                                                                                 1
# IC-procedure succesvol doorlopen, maar onbereikbaar voor belafspraak.                                                                                                                                                                                                                              1
# Na lang aandringen IC gekregen. Door omstandigheden uiteindelijk geen telefonisch interview afgenomen.                                                                                                                                                                                             1
# contact gestaakt, participant onbereikbaar, huisarts wilt geen aanvullende contactgegevens verstrekken.                                                                                                                                                                                            1
# Deelnemer gebeld voor retour. Nog herstellende van COVID. Mocht later opnieuw contact opnemen, maar vanwege einde studie niet meer opnieuw benaderd.                                                                                                                                               1
# Contact gestaakt: participant heeft toestemmingformulier niet geretourneerd en is niet telefonisch bereikbaar.                                                                                                                                                                                     1
# Ten tijden van SAP-check: begin januari opname i.v.m. COVID. In combinatie met hogere leeftijd niet benaderd voor LTM FU.                                                                                                                                                                          1
# ICF van mevr. per abuis onder 'geen deelname' gefiled. Vanwege einde studie niet alsnog benaderd.                                                                                                                                                                                                  1
# Missed. Ik had bij deze pt opmerking 'check met AH' (vanwege hoge leeftijd?) gezet en daarna over het hoofd gezien. Vanwege einde vd studie niet meer benaderd.                                                                                                                                    1
# GD LTM. Missed. Note voor overleg deelname - meneer slechthorend? Maar daarna over het hoofd gezien. Vanwege het einde van de studie niet meer benaderd.                                                                                                                                           1
# Missed. Mevrouw had ICF niet correct ingevuld, daarna over het hoofd gezien en i.v.m. einde vd studie niet meer benaderd.                                                                                                                                                                          1
# Mevrouw heeft Parkinson en op basis van informatie SAP lijkt ze niet meer in staat om telefonisch iemand te woord te staan - echtgenoot doet de TC's. Daarom afgezien van benadering.                                                                                                              1
# Deelname HBS afgebroken bij de baseline meting, omdat MRI niet mogelijk was                                                                                                                                                                                                                        1
# Geen geschikte kandidaat ivm toevalsbevinding op baseline                                                                                                                                                                                                                                          1
# patiënt heeft het informed consent formulier getekend om deel te nemen aan de follow-up. Echter, patiënt is nadien onbereikbaar voor het inplannen van het interview                                                                                                                               1
# dhr. is onbereikbaar                                                                                                                                                                                                                                                                               1
# Missed. EC wilde deze deelname met Astrid bespreken voor inclusie. Daarna over het hoofd gezien.                                                                                                                                                                                                   1
# Contact gestaakt, participant heeft toestemmingsformulier niet geretourneerd en is niet bereikbaar per telefoon.                                                                                                                                                                                   1
# contact gestaakt: meneer heeft IC niet geretourneerd en neemt telefoon niet op.                                                                                                                                                                                                                    1
# participant heeft op baseline-toestemmingsformulier aangegeven niet te willen worden benaderd voor volgend wetenschappelijk onderzoek. Tevens is meneer op 04-03-2019 overleden. Oorzaak van overlijden: terminale nierinsufficiëntie, coronair lijden en verminderde linker ventrikelfunctie.     1
# informed consent procedure is niet gelukt bij vermoeden beperkt cognitief functioneren van de participant.                                                                                                                                                                                         1
# Heeft telefonisch aangegeven mee te willen doen, maar heeft vervolgens nooit toestemmingsformulier geretourneerd.                                                                                                                                                                                  1
# Contact gestaakt: patiënt heeft toestemmingsformulier niet geretourneerd en is niet bereikbaar.                                                                                                                                                                                                    1
# Niet benaderd omdat meneer FU2 weigerde, reden hiervoor was: patiënt is teveel achteruitgegaan.                                                                                                                                                                                                    1
# Telefonisch gesproken, participant heeft het erg druk gehad en gaat nog een keer naar de PIF kijken, maar heeft vervolgens nooit toestemmingsformulier geretourneerd.                                                                                                                              1
# contact gestaakt: meneer heeft IC niet geretourneerd en neemt de telefoon niet op.                                                                                                                                                                                                                 1
# Heeft telefonisch aangegeven te willen participeren, maar heeft vervolgens nooit toestemmingsformulier geretourneerd.                                                                                                                                                                              1
# Participant heeft toestemmingsformulier niet geretourneerd en er is geen telefoonnummer bekend.                                                                                                                                                                                                    1
# Participant woont in beschermde woongroep, onbekend of post goed is aangekomen, medewerker aldaar wilt persoonlijke nummer van participant niet delen.                                                                                                                                             1
# Participant is verhuisd naar het buitenland.                                                                                                                                                                                                                                                       1
# informed consent procedure is niet gelukt bij vermoeden beperkt cognitief functioneren van de patiënt.                                                                                                                                                                                             1
# Participant heeft op baseline-toestemmingsformulier niet aangegeven of zij benaderd mag worden voor volgend wetenschappelijk onderzoek.                                                                                                                                                            1
# reden onbekend, partner heeft op 04-05-2021 gemaild naar J. van Alphen dat meneer niet deel zal nemen.                                                                                                                                                                                             1
# IC-procedure succesvol doorlopen, maar het enige telefoonnummer dat bekend is (ook bij huisarts) werkt niet.                                                                                                                                                                                       1
# Participant heeft aan de telefoon gezegd dat de envelop vandaag is gekomen en dat hij het gaat lezen, heeft vervolgens nooit IC geretourneerd.                                                                                                                                                     1
# participant heeft IC niet geretourneerd en is niet bereikbaar.                                                                                                                                                                                                                                     1
# participant heeft IC niet geretourneerd en is niet bereikbaar, tevens ernstig ziek: achteruitgang AD en gemetasteerde prostaatkanker.                                                                                                                                                              1
# participant heeft op baseline-toestemmingsformulier aangegeven niet te willen worden benaderd voor volgend wetenschappelijk onderzoek. Tevens is deelnemer overleden op 12-09-2017 middels met plegen van euthanasie wegens de ziekte van Alzheimer.                                               1
# contact gestaakt: patiënt heeft IC niet geretourneerd en is niet bereikbaar.                                                                                                                                                                                                                       1
# Contact gestaakt, participant heeft toestemmingsformulier niet geretourneerd en is telefonisch niet bereikbaar.                                                                                                                                                                                    1
# IC-procedure succesvol doorlopen, maar is niet bereikbaar voor belafspraak.                                                                                                                                                                                                                        1
# Partner telefonisch gesproken, die ging participant helpen herinneren, vervolgens toestemmingformulier nooit ontvangen.                                                                                                                                                                            1
# Contact gestaakt, participant heeft toestemmingformulier niet geretourneerd en is telefonisch niet bereikbaar.                                                                                                                                                                                     1
# Toestemmingsformulier niet geretourneerd na naar nieuw adres te hebben gestuurd.                                                                                                                                                                                                                   1
# IC-procedure succesvol doorlopen maar niet bereikbaar voor belafspraak.                                                                                                                                                                                                                            1
# Telefonisch bevestigt dat participant PIF heeft doorgelezen en waarschijnlijk gaat tekenen en retourneren, heeft dat vervolgens nooit gedaan.                                                                                                                                                      1
# participant heeft bij FU2 aangegeven niet meer te willen worden benaderd voor wetenschap, het was te belastend.                                                                                                                                                                                    1
# niet gelukt om de informed consent procedure en het interview voor het einde van de studie af te ronden                                                                                                                                                                                            1
#
# ── T4_dementie_anders_E4_C12 ──
# T4_dementie_anders_E4_C12
# MCI door CAA                                                                     1
# Vasculaire MCI                                                                   1
# LATE                                                                             1
# ziekte van Alzheimer met vasculaire bijmenging                                   1
# Multidomein MCI bij multipele herseninfarcten en wisselende stemmingsklachten    1
# MCIm multidomein MCI op basis van vasculaire schade                              1

# %%
# Cell 11 – Build outcomes and subset for BN variables

outcomes, outcomes_sub = build_outcomes(df_fu)

# Load codebook and filter layer information
bn_vars = pd.read_excel(config.codebook_path, sheet_name="Items")
bn_vars.loc[bn_vars["VARIABLE NAME"] == "DROPOUT REASON", "LAYER"] = "L9 – Dropout"

subset, bn_vars_filter = prepare_subset(df_fu, bn_vars)

LOGGER.info("Outcomes shape: %s", outcomes.shape)
LOGGER.info("Subset shape before merge: %s", subset.shape)
# Out:
# WARNING Outcome columns missing from fu dataset and will be filled with NaN: ['T2_CVA_type_overig_E3_C11']
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# INFO Outcomes shape: (566, 47)
# INFO Subset shape before merge: (566, 55)

# %%
# Cell 12 – Merge outcomes into subset and harmonise columns

df_final = subset.merge(outcomes_sub, how="left", on="patientID")

harmonise_columns(df_final, bn_vars_filter)

# Add extra layer rows and deduplicate
extra = pd.DataFrame(EXTRA_LAYER_ROWS, columns=["LAYER", "VARIABLE NAME"])
extra.loc[extra["VARIABLE NAME"] == "DROPOUT REASON", "LAYER"] = "L9 – Dropout"
bn_vars_filter = pd.concat([bn_vars_filter, extra], ignore_index=True)
bn_vars_filter.loc[bn_vars_filter["VARIABLE NAME"] == "DROPOUT REASON", "LAYER"] = "L9 – Dropout"
bn_vars_filter = bn_vars_filter.drop_duplicates(subset=["VARIABLE NAME"])

df_final = normalise_string_categories(df_final)

# Convert labelled columns via simple string title-case for object columns
df_final = df_final.apply(lambda col: col.astype(str).str.title() if col.dtype == object else col)

LOGGER.info("df_final shape after harmonisation: %s", df_final.shape)
df_final.head()
# Out:
# INFO df_final shape after harmonisation: (566, 58)
#    PATIENTID                 PATIENTENGROEP     SEX        AGE   PTAU181        NFL        GFAP        AB40       AB42  CHOLESTEROL_TOTAAL  CHOLESTEROL_LDL  CHOLESTEROL_HDL  \
# 0     1001.0  Vascular Cognitive Impairment  Female  58.929500  2.167700  11.135018  153.128545  109.304989   6.956860                 5.0              3.0              1.4
# 1     1002.0  Vascular Cognitive Impairment    Male  57.464750  0.951074  12.241553  105.655261  113.991180   5.197182                 6.4              4.1              1.2
# 2     1003.0                      Hartfalen    Male  62.464066  0.944169  17.346210   69.483929  100.077280   6.615191                 3.9              1.9              1.2
# 3     1004.0                      Hartfalen  Female  81.475702  3.123887  38.966101   93.721259  144.314806  11.023838                 2.8              1.2              1.0
# 4     1005.0                      Hartfalen  Female  85.483915  3.308229  47.927891  180.980266  129.650860   8.041534                 5.7              2.4              2.8
#
#        ROKEN  ROKEN_HOEVEEL_JAAR_A  ROKEN_GESTOPT  ROKEN_HOEVEEL_PER_DAG_A                                    T2_ROKEN_E3_C10                                           DIABETES  \
# 0        Nee                   0.0            NaN                      0.0                                                Nee                                                Nee
# 1  Niet Meer                   2.0           40.0                      8.0  Niet Meer, Ik Was Al Gestopt Vã³Ã³R De Baselin...                                                Nee
# 2  Niet Meer                  20.0            7.0                     20.0  Niet Meer, Ik Was Al Gestopt Vã³Ã³R De Baselin...                                                Nee
# 3        Nee                   0.0            NaN                      0.0                                                Nee  Ja, Waarvoor Alleen Tabletten (Orale Antidiabe...
# 4        Nee                   0.0            NaN                      0.0                                                Nee                                                Nee
#
#    SYSTOLISCH_A  SYSTOLISCH_B  SYSTOLISCH_C  SYSTOLISCH_D  SYSTOLISCH_E  SYSTOLISCH_F  T2_SYSTOLISCH_A_E3_C10  T2_SYSTOLISCH_B_E3_C10  T2_SYSTOLISCH_C_E3_C10  \
# 0         145.0         143.0         136.0         142.0         148.0         136.0                   182.0                   189.0                   189.0
# 1         148.0         139.0         138.0         154.0         137.0         144.0                   158.0                   153.0                   138.0
# 2         147.0         144.0         136.0         143.0         157.0         169.0                   170.0                   168.0                   162.0
# 3         162.0         158.0         150.0         150.0         161.0         155.0                   157.0                   157.0                   142.0
# 4         159.0         129.0         178.0         139.0         138.0         159.0                   136.0                   123.0                   140.0
#
#    T2_SYSTOLISCH_D_E3_C10  T2_SYSTOLISCH_E_E3_C10  T2_SYSTOLISCH_F_E3_C10  MMSE_TOTAAL  STARKSTEIN  CDR BLOEDDRUK_MEDICATIE CHOLESTEROL_MEDICATIE  TIA                CVA  \
# 0                   180.0                   195.0                   174.0         29.0        17.0  0.5                  Ja                    Ja  Nee                Nee
# 1                   155.0                   162.0                   153.0         28.0         7.0  0.5                  Ja                    Ja  Nee                Nee
# 2                   164.0                   167.0                   165.0         29.0        15.0  0.5                 Nee                    Ja  Nee  Ja, Herseninfarct
# 3                   149.0                   149.0                   147.0         24.0         9.0  0.0                  Ja                    Ja  Nee                Nee
# 4                   141.0                   139.0                   144.0         27.0        14.0  0.5                 Nan                   Nan  Nee                Nee
#
#    DIASTOLISCH_A  DIASTOLISCH_B  TRIGLYCERIDEN   PWV  NEURORAD_SVD_SCORE  Q_IC_TISSUE_TOTAL_INTRACRANIAL_VOLUME_ML  Q_IC_TISSUE_TOTAL_BRAIN_VOLUME_ML  \
# 0           92.0           84.0            1.3  7.08                 0.0                               1320.294537                        1095.265128
# 1           92.0           91.0            2.4  7.00                 1.0                               1460.491170                        1241.560744
# 2           93.0           91.0            1.8  7.27                 2.0                               1484.846495                        1114.681871
# 3           99.0           93.0            1.2  7.08                 NaN                               1206.089583                         904.348939
# 4           72.0           72.0            1.1  6.63                 1.0                               1347.949212                        1013.629183
#
#    I_IC_GM_HIPPOCAMPUS_LEFT_VOLUME_ML  I_IC_GM_HIPPOCAMPUS_RIGHT_VOLUME_ML  I_IC_CBF_GRAYMATTER_MEAN_ML100GMIN     BCS_1     BCS_2  SYS_BP  DIAS_BP    HV_ICV    TBV_ICV      CBF  \
# 0                            2.037932                             1.871610                             55.5574       NaN       NaN   144.0     88.0  0.148056  82.956121  55.5574
# 1                            2.039206                             2.115254                             50.0680 -0.157932 -0.516713   143.5     91.5  0.142228  85.009808  50.0680
# 2                            2.043294                             1.402859                             56.1078 -1.148846  0.197913   145.5     92.0  0.116044  75.070512  56.1078
# 3                            1.546857                             1.606668                             55.5076       NaN       NaN   160.0     96.0  0.130733  74.981904  55.5076
# 4                            1.679896                             1.975974                             71.3985  0.765761  0.442229   144.0     72.0  0.135609  75.197876  71.3985
#
#    MACE T4_DROPOUT_REASON OUTCOME_MACE OUTCOME_CDR_INCREASE
# 0     0             Other   Unobserved           Unobserved
# 1     0        No Dropout           No                   No
# 2     1           Refusal   Unobserved           Unobserved
# 3     1           Refusal   Unobserved           Unobserved
# 4     0          Deceased   Unobserved           Unobserved

# %%
# ── Diagnostic: verify SCORE2 inputs and DIABETES/ROKEN values ──────────────
print("=== SCORE2 input columns ===")
score2_needed = ["AGE", "SEX", "SYS_BP", "CHOLESTEROL_TOTAAL", "CHOLESTEROL_HDL", "ROKEN", "DIABETES"]
for col in score2_needed:
    if col in df_final.columns:
        n_valid = df_final[col].notna().sum()
        sample = df_final[col].dropna().iloc[:3].tolist()
        print(f"  ✓ {col:<25} non-null={n_valid}  sample={sample}")
    else:
        print(f"  ✗ {col:<25} *** MISSING — will cause all-NA SCORE2 ***")

print("\n=== DIABETES unique values ===")
if "DIABETES" in df_final.columns:
    display(df_final["DIABETES"].value_counts(dropna=False).rename("count").to_frame())
else:
    print("  ✗ DIABETES column not found in df_final")

print("\n=== ROKEN unique values ===")
if "ROKEN" in df_final.columns:
    display(df_final["ROKEN"].value_counts(dropna=False).rename("count").to_frame())
else:
    print("  ✗ ROKEN column not found in df_final")

print("\n=== Columns in df_fu that look like cholesterol / roken / diabetes ===")
hint_cols = [c for c in df_fu.columns if any(kw in c.lower() for kw in ["chol", "roken", "diab"])]
for c in hint_cols:
    print(f"  {c}")
# Out:
# === SCORE2 input columns ===
#   ✓ AGE                       non-null=566  sample=[58.92950034223135, 57.464750171115675, 62.46406570841889]
#   ✓ SEX                       non-null=566  sample=['Female', 'Male', 'Male']
#   ✓ SYS_BP                    non-null=563  sample=[144.0, 143.5, 145.5]
#   ✓ CHOLESTEROL_TOTAAL        non-null=554  sample=[5.0, 6.4, 3.9]
#   ✓ CHOLESTEROL_HDL           non-null=554  sample=[1.4, 1.2, 1.2]
#   ✓ ROKEN                     non-null=566  sample=['Nee', 'Niet Meer', 'Niet Meer']
#   ✓ DIABETES                  non-null=566  sample=['Nee', 'Nee', 'Nee']
#
# === DIABETES unique values ===
#                                                     count
# DIABETES
# Nee                                                   480
# Ja, Waarvoor Alleen Tabletten (Orale Antidiabet...     42
# Ja, Waarvoor Insuline                                  25
# Ja, Waarvoor Alleen Leefstijladviezen                  16
# Nan                                                     3
# === ROKEN unique values ===
#            count
# ROKEN
# Niet Meer    321
# Nee          150
# Ja            93
# Nan            2
# === Columns in df_fu that look like cholesterol / roken / diabetes ===
#   T0_roken_E1_C1
#   T0_roken_hoeveel_jaar_a_E1_C1
#   T0_roken_hoeveel_jaar_b_E1_C1
#   T0_roken_gestopt_E1_C1
#   T0_roken_hoeveel_per_dag_a_E1_C1
#   T0_roken_hoeveel_per_dag_b_E1_C1
#   T0_cholesterol_E1_C1
#   T0_cholesterol_medicatie_E1_C1
#   T0_diabetes_E1_C1
#   T0_ECG_echolocatie_E1_C1
#   T0_cholesterol_totaal_E1_C6
#   T0_cholesterol_LDL_E1_C6
#   T0_cholesterol_HDL_E1_C6
#   T2_roken_E3_C10
#   T2_ECG_echolocatie_E3_C10

# %%
# Cell 13 – Compute SCORE2 and build reduced dataset

df_clean_score = df_final.copy()

# ── 1. Fill sparse NaNs in categorical inputs ─────────────────────────────
#   (DIABETES n=3, ROKEN n=2 are missing; treat as 'Nee' — clinically safe
#    given the tiny numbers and conservative default.)
for _col, _fill in [("DIABETES", "Nee"), ("ROKEN", "Nee")]:
    if _col in df_clean_score.columns:
        # After cell-12 title-casing NaN→"Nan"; catch both real NaN and the string
        _s = df_clean_score[_col]
        _bad = _s.isna() | (_s.astype(str).str.strip().str.casefold() == "nan")
        df_clean_score.loc[_bad, _col] = _fill
        if _bad.sum():
            print(f"  Filled {_bad.sum()} missing {_col} values with '{_fill}'")

# ── 2. Sex, smoking, diabetes binary flags ────────────────────────────────
sex_series = df_clean_score.get("SEX")
sex_lower = sex_series.astype(str).str.lower() if sex_series is not None \
            else pd.Series("male", index=df_clean_score.index)
df_clean_score["SEX_SCORE"] = np.where(sex_lower == "female", "female", "male")

_roken = df_clean_score.get("ROKEN", pd.Series("nee", index=df_clean_score.index))
df_clean_score["ROKEN_SCORE"] = np.where(
    _roken.astype(str).str.strip().str.casefold() == "ja", 1, 0
)

_diabetes = df_clean_score.get("DIABETES", pd.Series("nee", index=df_clean_score.index))
df_clean_score["DIABETES_SCORE"] = np.where(
    _diabetes.astype(str).str.strip().str.casefold().str.startswith("nee"), 0, 1
)

# ── 3. Resolve cholesterol column names (handle naming variants) ──────────
def _find_col(df: pd.DataFrame, *candidates: str) -> str | None:
    """Return the first candidate column that exists in df."""
    for c in candidates:
        if c in df.columns:
            return c
    return None

_chol_totaal = _find_col(df_clean_score,
    "CHOLESTEROL_TOTAAL", "CHOLESTEROL", "TOTAL_CHOLESTEROL", "CHOLESTEROL_TOTAL")
_chol_hdl    = _find_col(df_clean_score,
    "CHOLESTEROL_HDL", "HDL", "HDL_CHOLESTEROL")
_chol_ldl    = _find_col(df_clean_score,
    "CHOLESTEROL_LDL", "LDL", "LDL_CHOLESTEROL")

print(f"  CHOLESTEROL_TOTAAL → {_chol_totaal or '*** NOT FOUND ***'}")
print(f"  CHOLESTEROL_HDL    → {_chol_hdl    or '*** NOT FOUND ***'}")
print(f"  CHOLESTEROL_LDL    → {_chol_ldl    or '*** NOT FOUND ***'}")

# ── 4. Compute SCORE2 ─────────────────────────────────────────────────────
def row_score(row: pd.Series) -> float | None:
    try:
        age        = row.get("AGE")
        sys_bp     = row.get("SYS_BP")
        total_chol = row.get(_chol_totaal) if _chol_totaal else None
        total_hdl  = row.get(_chol_hdl)    if _chol_hdl    else None
        if any(v is None or (isinstance(v, float) and np.isnan(v))
               for v in [age, sys_bp, total_chol, total_hdl]):
            return None
        return score2(
            risk_region=config.risk_region,
            age=float(age),
            gender=row.get("SEX_SCORE", "male"),
            smoker=float(row.get("ROKEN_SCORE", 0)),
            systolic_bp=float(sys_bp),
            diabetes=float(row.get("DIABETES_SCORE", 0)),
            total_chol=float(total_chol),
            total_hdl=float(total_hdl),
        )
    except (TypeError, ValueError):
        return None

df_clean_score["SCORE_2"] = df_clean_score.apply(row_score, axis=1)

n_scores = df_clean_score["SCORE_2"].notna().sum()
n_total  = len(df_clean_score)
print(f"\n  SCORE_2: {n_scores}/{n_total} patients have a value "
      f"({'ALL NA — missing cholesterol columns above' if n_scores == 0 else 'OK'})")

# ── 5. Reduced column set for BN ──────────────────────────────────────────
reduced_cols = [
    "AGE", "SEX", "PTAU181", "NFL", "GFAP", "AB40", "AB42",
    "MMSE_TOTAAL", "STARKSTEIN", "CDR", "CVA", "NEURORAD_SVD_SCORE",
    "BCS_1", "BCS_2", "HV_ICV", "TBV_ICV", "CBF", "MACE",
    "OUTCOME_MACE", "OUTCOME_CDR_INCREASE", "T4_DROPOUT_REASON",
    "SCORE_2", "PATIENTENGROEP",
]
df_clean_reduced = df_clean_score[[c for c in reduced_cols if c in df_clean_score]].copy()

bn_vars_filter_2 = bn_vars_filter[bn_vars_filter["VARIABLE NAME"].isin(df_clean_reduced.columns)].copy()
bn_vars_filter_2["LAYER"] = bn_vars_filter_2["LAYER"].astype(str).str.strip()
bn_vars_filter_2.loc[bn_vars_filter_2["VARIABLE NAME"] == "DROPOUT REASON", "LAYER"] = "L9 – Dropout"
bn_vars_filter_2 = bn_vars_filter_2.drop_duplicates(subset=["VARIABLE NAME"])
bn_vars_filter_2.loc[bn_vars_filter_2["VARIABLE NAME"] == "DROPOUT REASON", "LAYER"] = "L9 – Dropout"

df_clean_reduced.rename(columns=NAME_MAPPING, inplace=True)
bn_vars_filter_2["VARIABLE NAME"] = bn_vars_filter_2["VARIABLE NAME"].replace(NAME_MAPPING)
bn_vars_filter_2.loc[bn_vars_filter_2["VARIABLE NAME"] == "DROPOUT REASON", "LAYER"] = "L9 – Dropout"

df_clean_reduced = translate_labels(df_clean_reduced)
df_clean_reduced = normalise_string_categories(df_clean_reduced)
enforce_domain_categories(df_clean_reduced)

LOGGER.info("df_clean_reduced shape: %s", df_clean_reduced.shape)
# Out:
# INFO df_clean_reduced shape: (566, 23)
#   Filled 3 missing DIABETES values with 'Nee'
#   Filled 2 missing ROKEN values with 'Nee'
#   CHOLESTEROL_TOTAAL → CHOLESTEROL_TOTAAL
#   CHOLESTEROL_HDL    → CHOLESTEROL_HDL
#   CHOLESTEROL_LDL    → CHOLESTEROL_LDL
#
#   SCORE_2: 554/566 patients have a value (OK)

# %%
# Cell 14 – Imputation and final outputs

# Impute
df_imp = impute_dataframe(df_clean_reduced, config.seed)
enforce_domain_categories(df_imp)
if "ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY" in df_imp.columns:
    df_imp["ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY"] = df_imp[
        "ATHEROSCLEROTIC CARDIOVASCULAR DISEASE HISTORY"
    ].astype(str)

# Ensure output dir exists
output_dir = config.output_dir
output_dir.mkdir(parents=True, exist_ok=True)

# Write parquet outputs
df_clean_reduced.to_parquet(output_dir / "df.parquet", index=False)
df_imp.to_parquet(output_dir / "df_imp.parquet", index=False)
bn_vars_filter_2.to_parquet(output_dir / "bn_vars.parquet", index=False)

LOGGER.info("Wrote df.parquet (%s rows)", len(df_clean_reduced))
LOGGER.info("Wrote df_imp.parquet (%s rows)", len(df_imp))
LOGGER.info("Wrote bn_vars.parquet (%s rows)", len(bn_vars_filter_2))
# Out:
# /var/folders/k7/m876w0ts2n77lwt3x1dc25zc0000gp/T/ipykernel_35677/3229356615.py:14: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(series):
# INFO Wrote df.parquet (566 rows)
# INFO Wrote df_imp.parquet (566 rows)
# INFO Wrote bn_vars.parquet (22 rows)

# %%
# Count deceased participants whose death was NOT captured as MACE

# Total deceased at T2
deceased_t2 = df_final[df_final["DROPOUT_REASON"] == "Deceased"]
print(f"Deceased at T2: {len(deceased_t2)}")
print(f"  - of which MACE=Yes: {(deceased_t2['OUTCOME_MACE'] == 1).sum()}")
print(f"  - of which MACE=No (non-cardiac death): {(deceased_t2['OUTCOME_MACE'] == 0).sum()}")

# Total deceased at T4
deceased_t4 = outcomes[outcomes["T4_dropout_reason"] == "Deceased"]
print(f"\nDeceased at T4: {len(deceased_t4)}")
print(f"  - of which MACE=Yes: {(deceased_t4['T4_Event_MACE'] == 1).sum()}")
print(f"  - of which MACE=No (non-cardiac death): {(deceased_t4['T4_Event_MACE'] == 0).sum()}")

# In the final outcome: how many ended up as Unobserved due to death?
deceased_any = outcomes[
    (outcomes["T2_dropout_reason"] == "Deceased") 
    | (outcomes["T4_dropout_reason"] == "Deceased")
]
print(f"\nTotal deceased (any timepoint): {len(deceased_any)}")
print(f"  - OUTCOME_MACE distribution:")
print(deceased_any["OUTCOME_MACE"].value_counts())
print(f"\n  - OUTCOME_CDR_INCREASE distribution:")
print(deceased_any["OUTCOME_CDR_INCREASE"].value_counts())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'T2_dropout_reason'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 4
#       1 # Count deceased participants whose death was NOT captured as MACE
#       2
#       3 # Total deceased at T2
# ----> 4 deceased_t2 = df_final[df_final["T2_dropout_reason"] == "Deceased"]
#       5 print(f"Deceased at T2: {len(deceased_t2)}")
#       6 print(f"  - of which MACE=Yes: {(deceased_t2['T2_Event_MACE'] == 1).sum()}")
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'T2_dropout_reason'
